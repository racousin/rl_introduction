# %%
# !pip install 'stable-baselines3[extra]'
# Out:
# ...
#   Obtaining dependency information for stable-baselines3[extra] from https://files.pythonhosted.org/packages/1e/43/d4b83e644c7e42d90d76a1987fb98a2ab286a2b5593350210ca8efcc378e/stable_baselines3-2.2.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for torch>=1.13 from https://files.pythonhosted.org/packages/a7/ad/fbe7d4cffb76da4e478438853b51305361c719cff929ab70a808e7fb75e7/torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl.metadata
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/d9/64/7fdfb9386511cd6805451e012c537073a79a958a58795c4e602e538c388c/opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for tensorboard>=2.9.1 from https://files.pythonhosted.org/packages/3a/d0/b97889ffa769e2d1fdebb632084d5e8b53fc299d43a537acee7ec0c021a3/tensorboard-2.16.2-py3-none-any.whl.metadata
# ...

# %%
import gymnasium as gym
import stable_baselines3 as sb3

# Create environment
env = gym.make('LunarLander-v2')

# Initialize the model
model = sb3.PPO('MlpPolicy', env, verbose=1)

# Train the model
model.learn(total_timesteps=1000000)  # You might want to increase this for better results

# Save the model
model.save("model")

# Don't forget to close the environment
env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.3     |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    fps             | 1745     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.6        |
# |    ep_rew_mean          | -171        |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012529191 |
# |    clip_fraction        | 0.089       |
# ...

# %%
import requests

# Endpoint URL
url = 'https://rlarena.com/api/direct_attache_agents_notebook/competition/1'

# Your credentials and agent details
data = {
    'username': 'testuser',
    'password': 'testpassword',
    'agent_attach_name': 'My LunarLander Agent',
}

# Files to upload: agent.py and the model
files = {
    'model': ('model.zip', open('model.zip', 'rb')),  # Adjust if necessary
    'agent_code': ('agent.py', open('agent.py', 'r')),  # The agent code
}

# Make the POST request
response = requests.post(url, data=data, files=files)

# Check the response
print(response.json())
# Out:
# {'attache_agent_id': 3, 'message': 'Uploaded successfully: model.zip, agent.py'}
